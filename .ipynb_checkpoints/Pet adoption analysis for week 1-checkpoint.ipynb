# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_4 = pd.read_csv("C:\\Users\\Kolade\\Documents\\Datasets\\pet_adoption for cleaning.csv")
df_4.tail()
# Out:
#     pet_id pet_name  species               breed  age_years  gender    color  \
# 195  P0196  Melissa  Hamster             Chinese          8    Male    White
# 196  P0197    Ricky      Dog  Labrador Retriever          4  Female   Golden
# 197  P0198    Carly   Rabbit       Flemish Giant          5    Male  Spotted
# 198  P0199      Don      Dog          Great Dane          1    Male    Mixed
# 199  P0200    Caleb     Bird              Canary          5    Male   Golden
#
#     arrival_date  adopted adoption_date adopter_id    adopter_name  \
# 195   11/10/2024    False    11/28/2024        NaN             NaN
# 196     4/9/2025    False      5/6/2025        NaN             NaN
# 197     2/2/2024    False     2/13/2024        NaN             NaN
# 198   11/11/2024     True    12/25/2024      A0199  Derek Martinez
# 199   10/16/2024    False     11/7/2024        NaN             NaN
#
#      adopter_age    adopter_city  adopter_previous_pets Unnamed: 15
# 195           -1             NaN                      0         NaN
# 196           -1             NaN                      0         NaN
# 197           -1             NaN                      0         NaN
# 198           25  South Michelle                      1         NaN
# 199           -1             NaN                      0         NaN

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pet_id                 200 non-null    object
#  1   pet_name               200 non-null    object
#  2   species                200 non-null    object
#  3   breed                  200 non-null    object
#  4   age_years              200 non-null    int64
#  5   gender                 200 non-null    object
#  6   color                  200 non-null    object
#  7   arrival_date           200 non-null    object
#  8   adopted                200 non-null    bool
#  9   adoption_date          200 non-null    object
#  10  adopter_id             118 non-null    object
#  11  adopter_name           118 non-null    object
#  12  adopter_age            200 non-null    int64
#  13  adopter_city           118 non-null    object
#  14  adopter_previous_pets  200 non-null    int64
#  15  Unnamed: 15            4 non-null      object
# dtypes: bool(1), int64(3), object(12)
# memory usage: 23.8+ KB

# %%
df_4['S/N'] = np.arange(1, 201)

df_4 = df_4.set_index(df_4['S/N'])
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pet_id                 200 non-null    object
#  1   pet_name               200 non-null    object
#  2   species                200 non-null    object
#  3   breed                  200 non-null    object
#  4   age_years              200 non-null    int64
#  5   gender                 200 non-null    object
#  6   color                  200 non-null    object
#  7   arrival_date           200 non-null    object
#  8   adopted                200 non-null    bool
#  9   adoption_date          200 non-null    object
#  10  adopter_id             118 non-null    object
#  11  adopter_name           118 non-null    object
#  12  adopter_age            200 non-null    int64
#  13  adopter_city           118 non-null    object
#  14  adopter_previous_pets  200 non-null    int64
#  15  Unnamed: 15            4 non-null      object
#  16  S/N                    200 non-null    int32
# dtypes: bool(1), int32(1), int64(3), object(12)
# memory usage: 25.2+ KB

# %%
df_4[['adopter_name', 'adopter_city']] = df_4[['adopter_name', 'adopter_city']].fillna('Unknown')

# %%
df_4.loc[199, 'adopter_id'] = 'A0200'
df_4.tail()
# Out:
#     pet_id pet_name  species               breed  age_years  gender    color  \
# S/N
# 196  P0196  Melissa  Hamster             Chinese          8    Male    White
# 197  P0197    Ricky      Dog  Labrador Retriever          4  Female   Golden
# 198  P0198    Carly   Rabbit       Flemish Giant          5    Male  Spotted
# 199  P0199      Don      Dog          Great Dane          1    Male    Mixed
# 200  P0200    Caleb     Bird              Canary          5    Male   Golden
#
#     arrival_date  adopted adoption_date adopter_id    adopter_name  \
# S/N
# 196   11/10/2024    False    11/28/2024        NaN         Unknown
# 197     4/9/2025    False      5/6/2025        NaN         Unknown
# 198     2/2/2024    False     2/13/2024        NaN         Unknown
# 199   11/11/2024     True    12/25/2024      A0200  Derek Martinez
# 200   10/16/2024    False     11/7/2024        NaN         Unknown
#
#      adopter_age    adopter_city  adopter_previous_pets Unnamed: 15  S/N
# S/N
# 196           -1         Unknown                      0         NaN  196
# 197           -1         Unknown                      0         NaN  197
# 198           -1         Unknown                      0         NaN  198
# 199           25  South Michelle                      1         NaN  199
# 200           -1         Unknown                      0         NaN  200

# %%
# df_4['adopter_id'] = df_4['adopter_id'].interpolate()
# df_4['adopter_id']

# Extract numbers from existing codes
# Drop NaN temporarily to get valid codes
codes = df_4['adopter_id'].dropna().str.extract(r'A(\d+)', expand=False).astype(int)

# Generate full sequence from min to max
full_range = range(codes.min(), codes.max() + 1)

# Create full list of codes
full_codes = []
for num in full_range:
    code = f"A{str(num).zfill(4)}"
    full_codes.append(code)
    
# full_codes = [f"A{str(num).zfill(4)}" for num in full_range]

# # Assign back to the DataFrame
df_4['adopter_id'] = full_codes
df_4.head()
# Out:
#     pet_id pet_name species              breed  age_years  gender    color  \
# S/N
# 1    P0001   Sandra     Dog  Yorkshire Terrier          2  Female    White
# 2    P0002    Brian     Cat          Tonkinese          1  Female   Golden
# 3    P0003  Timothy    Bird      Amazon Parrot          4    Male  Spotted
# 4    P0004     Karl     Dog    German Shepherd          1  Female    White
# 5    P0005    Sarah  Rabbit              Dutch          1  Female  Spotted
#
#     arrival_date  adopted adoption_date adopter_id      adopter_name  \
# S/N
# 1     10/10/2024     True     3/11/2025      A0001      Megan Rogers
# 2       9/9/2023     True     2/10/2024      A0002  Jonathan Hawkins
# 3      10/3/2023    False    10/17/2023      A0003           Unknown
# 4      7/28/2024     True     8/12/2024      A0004    Natalie Rivera
# 5      2/21/2024    False     2/26/2024      A0005           Unknown
#
#      adopter_age   adopter_city  adopter_previous_pets  \
# S/N
# 1             56      Mcgeestad                      1
# 2             18      Geneshire                      2
# 3             -1        Unknown                      0
# 4             51  North Richard                      3
# 5             -1        Unknown                      0
#
#                                            Unnamed: 15  S/N
# S/N
# 1    -Analyzing adoption trends by species, breed, ...    1
# 2      -Predicting the likelihood or speed of adoption    2
# 3        -Visualizing demographic patterns of adopters    3
# 4    -Practicing data preprocessing with no missing...    4
# 5                                                  NaN    5

# %%
df_4.tail()
# Out:
#     pet_id pet_name  species               breed  age_years  gender    color  \
# S/N
# 196  P0196  Melissa  Hamster             Chinese          8    Male    White
# 197  P0197    Ricky      Dog  Labrador Retriever          4  Female   Golden
# 198  P0198    Carly   Rabbit       Flemish Giant          5    Male  Spotted
# 199  P0199      Don      Dog          Great Dane          1    Male    Mixed
# 200  P0200    Caleb     Bird              Canary          5    Male   Golden
#
#     arrival_date  adopted adoption_date adopter_id    adopter_name  \
# S/N
# 196   11/10/2024    False    11/28/2024      A0196         Unknown
# 197     4/9/2025    False      5/6/2025      A0197         Unknown
# 198     2/2/2024    False     2/13/2024      A0198         Unknown
# 199   11/11/2024     True    12/25/2024      A0199  Derek Martinez
# 200   10/16/2024    False     11/7/2024      A0200         Unknown
#
#      adopter_age    adopter_city  adopter_previous_pets Unnamed: 15  S/N
# S/N
# 196           -1         Unknown                      0         NaN  196
# 197           -1         Unknown                      0         NaN  197
# 198           -1         Unknown                      0         NaN  198
# 199           25  South Michelle                      1         NaN  199
# 200           -1         Unknown                      0         NaN  200

# %%
df_4 = df_4.drop('Unnamed: 15', axis='columns')
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pet_id                 200 non-null    object
#  1   pet_name               200 non-null    object
#  2   species                200 non-null    object
#  3   breed                  200 non-null    object
#  4   age_years              200 non-null    int64
#  5   gender                 200 non-null    object
#  6   color                  200 non-null    object
#  7   arrival_date           200 non-null    object
#  8   adopted                200 non-null    bool
#  9   adoption_date          200 non-null    object
#  10  adopter_id             200 non-null    object
#  11  adopter_name           200 non-null    object
#  12  adopter_age            200 non-null    int64
#  13  adopter_city           200 non-null    object
#  14  adopter_previous_pets  200 non-null    int64
#  15  S/N                    200 non-null    int32
# dtypes: bool(1), int32(1), int64(3), object(11)
# memory usage: 29.7+ KB

# %%
df_4.head()
# Out:
#     pet_id pet_name species              breed  age_years  gender    color  \
# S/N
# 1    P0001   Sandra     Dog  Yorkshire Terrier          2  Female    White
# 2    P0002    Brian     Cat          Tonkinese          1  Female   Golden
# 3    P0003  Timothy    Bird      Amazon Parrot          4    Male  Spotted
# 4    P0004     Karl     Dog    German Shepherd          1  Female    White
# 5    P0005    Sarah  Rabbit              Dutch          1  Female  Spotted
#
#     arrival_date  adopted adoption_date adopter_id      adopter_name  \
# S/N
# 1     10/10/2024     True     3/11/2025      A0001      Megan Rogers
# 2       9/9/2023     True     2/10/2024      A0002  Jonathan Hawkins
# 3      10/3/2023    False    10/17/2023      A0003           Unknown
# 4      7/28/2024     True     8/12/2024      A0004    Natalie Rivera
# 5      2/21/2024    False     2/26/2024      A0005           Unknown
#
#      adopter_age   adopter_city  adopter_previous_pets  S/N
# S/N
# 1             56      Mcgeestad                      1    1
# 2             18      Geneshire                      2    2
# 3             -1        Unknown                      0    3
# 4             51  North Richard                      3    4
# 5             -1        Unknown                      0    5

# %%
df_4['adopter_city'].unique()
# Out:
# array(['Mcgeestad', 'Geneshire', 'Unknown', 'North Richard',
#        'Port Sarachester', 'New Rachelview', 'Lake Jonathan',
#        'Port Timothy', 'Marychester', 'Joyton', 'Camposton',
#        'West Johnfurt', 'Millerside', 'Lake Melvinmouth', 'Andreaview',
#        'Ramoston', 'Nathanport', 'East Kellyburgh', 'Stevenville',
#        'Browntown', 'Port Tiffanyland', 'Hughesburgh', 'Kennedyfurt',
#        'Lake John', 'Pughbury', 'Lake Christopherfurt', 'Andersonton',
#        'East Amandaside', 'Port Christianberg', 'Williamville',
#        'Washingtonshire', 'Pattonville', 'North Philipchester',
#        'East Kenneth', 'South Brent', 'New James', 'North Nicole',
#        'Ashleyborough', 'Hallburgh', 'North Joanne', 'Lake Charles',
#        'South Nicole', 'Lake Lisatown', 'Samanthaview', 'Jenniferbury',
#        'West Maryburgh', 'East William', 'Cookburgh', 'New Brittanystad',
#        'Lake Ryanmouth', 'North Jennifer', 'South Sherry',
#        'Port Amandafort', 'East Johnland', 'New Gregoryland',
#        'Campbellside', 'West Gary', 'Lake Ana', 'South Stanley',
#        'South Robertland', 'Juliaburgh', 'Lake Tina', 'Christopherview',
#        'East Jessica', 'South Haroldstad', 'South Christopher',
#        'Lake Sean', 'Vaughnport', 'Houseville', 'New Nicholas',
#        'North Sarah', 'Donaldview', 'East Anthonyside', 'South Teresa',
#        'West Francisberg', 'Baileyshire', 'Melindabury', 'East Dawnburgh',
#        'New Rachelstad', 'Port Lauriebury', 'Stephenport', 'Donnafort',
#        'Aguilarberg', 'Allenchester', 'Dannyton', 'North Diana',
#        'Bradleyfort', 'Romerostad', 'Cortezmouth', 'Johnsonmouth',
#        'Jasminetown', 'New Patrick', 'Allenmouth', 'Port Stephenhaven',
#        'East Dennisborough', 'East Hectorbury', 'North Sarahview',
#        'Michaelaland', 'Bergerville', 'Jasminefurt', 'Stephensfurt',
#        'Laurenmouth', 'East Jessicaborough', 'Lake Richard',
#        'New Stevenborough', 'Morrowfurt', 'New Stephanieville',
#        'Sandersfurt', 'New Elijah', 'Williamsbury', 'Wareshire',
#        'New Cindy', 'North Oliviastad', 'Jaredland', 'Lake Christopher',
#        'West Stevenfort', 'Blackchester', 'South Michelle'], dtype=object)

# %%
# Matplotlib

# sns.barplot(
#     x='gender', 
#     y='price', 
#     df_4=df_4, 
#     color='blue');

# plt.bar(df_4['gender'] align='center', alpha=0.5)
# plt.xticks(gender, subject)
counts = df_4['gender'].value_counts()

counts.plot(kind='bar')

plt.title('Count of Gender')
# plt.xlabel('Department')
plt.ylabel('Count')
plt.show()

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pet_id                 200 non-null    object
#  1   pet_name               200 non-null    object
#  2   species                200 non-null    object
#  3   breed                  200 non-null    object
#  4   age_years              200 non-null    int64
#  5   gender                 200 non-null    object
#  6   color                  200 non-null    object
#  7   arrival_date           200 non-null    object
#  8   adopted                200 non-null    bool
#  9   adoption_date          200 non-null    object
#  10  adopter_id             200 non-null    object
#  11  adopter_name           200 non-null    object
#  12  adopter_age            200 non-null    int64
#  13  adopter_city           200 non-null    object
#  14  adopter_previous_pets  200 non-null    int64
#  15  S/N                    200 non-null    int32
# dtypes: bool(1), int32(1), int64(3), object(11)
# memory usage: 29.7+ KB

# %%
# Drop pet_id
# Pet_name: High cardinality
# species: Low card
# breed: high card
# color: low card
# date: convert to datetime
# adopter_id?
# adopter_name: high card
adopter_city: high card

df_4['adopter_city'].value_counts()[0:5]
# df_4['color'].unique()
# Out:
# adopter_city
# Unknown            82
# Christopherview     2
# Mcgeestad           1
# Baileyshire         1
# Romerostad          1
# Name: count, dtype: int64
